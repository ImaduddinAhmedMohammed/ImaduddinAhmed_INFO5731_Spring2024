# %% [markdown]
# <a href="https://colab.research.google.com/github/ImaduddinAhmedMohammed/ImaduddinAhmed_INFO5731_Spring2024/blob/main/Mohammed_Imad_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment 2**
#
# In this assignment, you will work on gathering text data from an open data source via web scraping or API. Following this, you will need to clean the text data and perform syntactic analysis on the data. Follow the instructions carefully and design well-structured Python programs to address each question.
#
# **Expectations**:
# *   Use the provided .*ipynb* document to write your code & respond to the questions. Avoid generating a new file.
# *   Write complete answers and run all the cells before submission.
# *   Make sure the submission is "clean"; *i.e.*, no unnecessary code cells.
# *   Once finished, allow shared rights from top right corner (*see Canvas for details*).
#
# * **Make sure to submit the cleaned data CSV in the comment section - 10 points**
#
# **Total points**: 100
#
# **Deadline**: Wednesday, at 11:59 PM.
#
# **Late Submission will have a penalty of 10% reduction for each day after the deadline.**

# %% [markdown]
# # Question 1 (40 points)
#
# Write a python program to collect text data from **either of the following sources** and save the data into a **csv file:**
#
# (1) Collect all the customer reviews of a product (you can choose any porduct) on amazon. [atleast 1000 reviews]
#
# (2) Collect the top 1000 User Reviews of a movie recently in 2023 or 2024 (you can choose any movie) from IMDB. [If one movie doesn't have sufficient reviews, collect reviews of atleast 2 or 3 movies]
#
# (3) Collect all the reviews of the top 1000 most popular software from G2 or Capterra.
#
# (4) Collect the **abstracts** of the top 10000 research papers by using the query "machine learning", "data science", "artifical intelligence", or "information extraction" from Semantic Scholar.
#
# (5) Collect all the information of the 904 narrators in the Densho Digital Repository.

# %%
""" The website "IMDB" that i used to scrape data from has a pagination key in
    the url that we get after using the inspect element and looking the network
    console. Since it has unique pagination key's for every time we load more
    reviews, I could not find a solution to make a loop and get 1000 reviews.
    I have added the url's for 5 pages individually that amounts to 100 reviews.
"""
from typing import Text
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np


# initiating a variable to  assign the first url
url1='https://www.imdb.com/title/tt15398776/reviews?ref_=tt_urv'
response = requests.get(url1)
print(response)
soup = BeautifulSoup(response.content, 'html.parser')
#print(soup)

# initiating the variables for the data we want to scrape on IMDB
title=[]
content=[]
rating=[]
name=[]

# using the find all function in beautiful soup to find the data we want
review_data1=soup.find_all('div',{'class':'lister-item mode-detail imdb-user-review collapsable'})
#print(review_data)
for reviews in review_data1:
  t=reviews.a.text.strip()  # the title we want is in 'a' tag in the html code
  title.append(t)
  txt=reviews.find('div',class_='text show-more__control').text.strip()
  content.append(txt)       # The content we want is in the given class in div tag.
  u_name=reviews.find('span',class_='display-name-link').text.strip()
  name.append(u_name)       # The User name is in the given class in span tag.
  rate=reviews.find('span',class_='rating-other-user-rating')
  if rate and rate.span:
    rating.append(rate.span.text.strip())   # The ratings we want is in the given class in span tag.
  else:                                     # we use conditional statement if-else
    rating.append(None)                     # since a few reviews do not have a rating.

# similarly do it for url 2,3,4 and 5.
url2='https://www.imdb.com/title/tt15398776/reviews/_ajax?ref_=undefined&paginationKey=g4xojermtizcs3ye7gvhtobtr3q4obj33ykdb6xqcwb32w3dnar26d27mjoenfo3b5frzogz4337gslgxpx6a'
response = requests.get(url2)
print(response)
soup = BeautifulSoup(response.content, 'html.parser')
#print(soup)
#
#title=[]
#content=[]
#rating=[]
#name=[]

review_data2=soup.find_all('div',{'class':'lister-item mode-detail imdb-user-review collapsable'})
#print(review_data)
for reviews in review_data2:
  t=reviews.a.text.strip()
  title.append(t)
  txt=reviews.find('div',class_='text show-more__control').text.strip()
  content.append(txt)
  u_name=reviews.find('span',class_='display-name-link').text.strip()
  name.append(u_name)
  rate=reviews.find('span',class_='rating-other-user-rating')
  if rate and rate.span:
    rating.append(rate.span.text.strip())
  else:
    rating.append(None)

url3='https://www.imdb.com/title/tt15398776/reviews/_ajax?ref_=undefined&paginationKey=g4u6dermtizcsyqa7gux7ojyrttmyaz43emtv77qcwb32w3enesk6c25mjohxkfmrk6mxq2bkwqf6tdjv44vu'
response = requests.get(url3)
print(response)
soup = BeautifulSoup(response.content, 'html.parser')

review_data3=soup.find_all('div',{'class':'lister-item mode-detail imdb-user-review collapsable'})
#print(review_data)
for reviews in review_data3:
  t=reviews.a.text.strip()
  title.append(t)
  txt=reviews.find('div',class_='text show-more__control').text.strip()
  content.append(txt)
  u_name=reviews.find('span',class_='display-name-link').text.strip()
  name.append(u_name)
  rate=reviews.find('span',class_='rating-other-user-rating')
  if rate and rate.span:
    rating.append(rate.span.text.strip())
  else:
    rating.append(None)

url4='https://www.imdb.com/title/tt15398776/reviews/_ajax?ref_=undefined&paginationKey=g4v6jermtizcsyqc7wuxvnbvrptmuaj23updb4hqcwb32w3dnas26bktmjoih4xlv6amnubzt24ktrngzcdpu'
response = requests.get(url4)
print(response)
soup = BeautifulSoup(response.content, 'html.parser')

review_data4=soup.find_all('div',{'class':'lister-item mode-detail imdb-user-review collapsable'})
#print(review_data)
for reviews in review_data4:
  t=reviews.a.text.strip()
  title.append(t)
  txt=reviews.find('div',class_='text show-more__control').text.strip()
  content.append(txt)
  u_name=reviews.find('span',class_='display-name-link').text.strip()
  name.append(u_name)
  rate=reviews.find('span',class_='rating-other-user-rating')
  if rate and rate.span:
    rating.append(rate.span.text.strip())
  else:
    rating.append(None)

url5='https://www.imdb.com/title/tt15398776/reviews/_ajax?ref_=undefined&paginationKey=g4w6ddbsqyxdo6ig62xxtmrtrtt4sbj22mod37xpdpj3qflinqr2ucctperta56iaw2vxvuvwae7fwzgb6oll7a'
response = requests.get(url5)
print(response)
soup = BeautifulSoup(response.content, 'html.parser')

review_data4=soup.find_all('div',{'class':'lister-item mode-detail imdb-user-review collapsable'})
#print(review_data)
for reviews in review_data4:
  t=reviews.a.text.strip()
  title.append(t)
  txt=reviews.find('div',class_='text show-more__control').text.strip()
  content.append(txt)
  u_name=reviews.find('span',class_='display-name-link').text.strip()
  name.append(u_name)
  rate=reviews.find('span',class_='rating-other-user-rating')
  if rate and rate.span:
    rating.append(rate.span.text.strip())
  else:
    rating.append(None)

#np.count_nonzero(title)
#content
#rate.text.replace('\n','')
#rating
#name

#create a csv file and add the data in it by creating a data frame.
Review_DF=pd.DataFrame({'Name':name, 'Title of Review':title, 'Rating by user':rating, 'User Review':content,})
Review_DF.to_csv('IMDB_OPP_Reviews.csv')
Review_DF.head(5)
Review_DF.tail(5)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
#                    Name         Title of Review Rating by user  \
# 95          sonshineboy       A Very Nolan Film              8
# 96  silviuzz-314-170010  Somewhat disappointing              7
# 97          towardsmoke       I Believe We Did!             10
# 98         ahamedfahimq   Unnecessarily lengthy              6
# 99           James_Farr        General takeaway              8
#
#                                           User Review
# 95  I can't help but wonder what this movie would'...
# 96  Way too long. It could have lasted 1h less wit...
# 97  In the realm of historical dramas, Christopher...
# 98  With great expectations, I went to watch this ...
# 99  As a general overview the movie has great paci...

# %% [markdown]
# # Question 2 (30 points)
#
# Write a python program to **clean the text data** you collected in the previous question and save the clean data in a new column in the csv file. The data cleaning steps include: [Code and output is required for each part]
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the stopwords list.
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
# Write code for each of the sub parts with proper comments.
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tokenize import word_tokenize
import re

data = pd.read_csv('IMDB_OPP_Reviews.csv')

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# Function to clean text
def clean_text(text):
    # Remove special characters and punctuations
    text = re.sub(r'[^a-zA-Z\s]', '', text)

    # Remove numbers
    text = re.sub(r'\d+', '', text)

    # Tokenize text
    tokens = word_tokenize(text)

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token.lower() not in stop_words]

    # Lowercase all texts
    tokens = [token.lower() for token in tokens]

    # Stemming
    #stemmer = PorterStemmer()
    #tokens = [stemmer.stem(token) for token in tokens]

    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]

    # Join tokens back to string
    clean_text = ' '.join(tokens)
    return clean_text

# Apply the cleaning function to your review column
data['Cleaned User Review'] = data['User Review'].apply(clean_text)

# Save the cleaned data to a new CSV file
data.to_csv('clean_csv_file.csv')
data.head(5)
data.tail(5)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#     Unnamed: 0                 Name         Title of Review  Rating by user  \
# 95          95          sonshineboy       A Very Nolan Film             8.0
# 96          96  silviuzz-314-170010  Somewhat disappointing             7.0
# 97          97          towardsmoke       I Believe We Did!            10.0
# 98          98         ahamedfahimq   Unnecessarily lengthy             6.0
# 99          99           James_Farr        General takeaway             8.0
#
#                                           User Review  \
# 95  I can't help but wonder what this movie would'...
# ...

# %% [markdown]
# # Question 3 (30 points)
#
# Write a python program to **conduct syntax and structure analysis of the clean text** you just saved above. The syntax and structure analysis includes:
#
# (1) **Parts of Speech (POS) Tagging:** Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) **Constituency Parsing and Dependency Parsing:** print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) **Named Entity Recognition:** Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
import pandas as pd
import spacy
from spacy import displacy
from collections import Counter

# Load spacy's English model
nlp = spacy.load("en_core_web_sm")

# Load the cleaned text data from the CSV file
data = pd.read_csv('clean_csv_file.csv')

# Initialize counters for POS and NER
total_pos_counts = Counter()
total_ner_counts = Counter()

# Iterate over each review in the dataset to update POS and NER counts
for review in data['Cleaned User Review'].dropna():  # Using dropna() to skip missing values
    doc = nlp(review)
    # Update POS counts
    pos_counts = Counter([token.pos_ for token in doc])
    total_pos_counts.update(pos_counts)

    # Update NER counts
    ner_counts = Counter([ent.label_ for ent in doc.ents])
    total_ner_counts.update(ner_counts)

# Display total POS and NER counts for the dataset
print("Total POS counts across all reviews:")
for pos, count in total_pos_counts.items():
    print(f"{pos}: {count}")

print("\nTotal NER counts across all reviews:")
for ner, count in total_ner_counts.items():
    print(f"{ner}: {count}")

def dependency_parsing(text):
    doc = nlp(text)
    displacy.render(doc, style="dep", jupyter=True, options={'distance': 90})


sample_text = data['Cleaned User Review'][0]
first_sentence = sample_text.split('.')[0]
print("Dependency parsing of the first sentence:")
dependency_parsing(first_sentence)
# Out:
# Total POS counts across all reviews:
# PRON: 233
# AUX: 364
# NOUN: 5680
# ADV: 1261
# VERB: 2861
# ADP: 209
# ADJ: 2440
# PROPN: 1873
# PART: 145
# X: 20
# NUM: 189
# SCONJ: 78
# DET: 68
# CCONJ: 10
# INTJ: 26
# SYM: 1
#
# Total NER counts across all reviews:
# GPE: 61
# PERSON: 267
# DATE: 54
# ORG: 34
# ORDINAL: 73
# FAC: 8
# NORP: 84
# EVENT: 9
# CARDINAL: 123
# TIME: 54
# LOC: 2
# QUANTITY: 1
# PRODUCT: 1
# Dependency parsing of the first sentence:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ef497188fd71486a9bb42a1e084ab251-0" class="displacy" width="12200" height="542.0" direction="ltr" style="max-width: none; height: 542.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">you</tspan>
# ...

# %% [markdown]
# # Mandatory Question
#
# Provide your thoughts on the assignment. What did you find challenging, and what aspects did you enjoy? Your opinion on the provided time to complete the assignment.

# %%
# Write your response below
"""
    This assignment helped me get more into web scraping. I was stuck trying to
    figure out a way of scraping data from IMDB website. The last question had
    me watch videos to learn how to do pos tagging and dependancy parsing. Once
    you get a hang of how to use various tools and functions, it is interesting
    to webscrape.
"""
